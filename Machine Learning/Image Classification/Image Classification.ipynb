# %% [markdown]
# <a href="https://colab.research.google.com/github/dnasywa/NutriScan/blob/main/capstone_RGB_model_and_recomendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## Overview

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# dataset Info
base_dir = '/content/drive/MyDrive/bangkit/dataset_iqbal'
class_names = ['FN', '-N', '-P', '-K']

# %% [markdown]
# ## Split

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %%
train_dir = base_dir + "/train"
validation_dir = base_dir + "/validation"
test_dir = base_dir + "/test"

# %%
# create the directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(validation_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %%
for class_name in class_names:
    folder_path = os.path.join(base_dir, class_name)

    if os.path.isdir(folder_path):
        images = os.listdir(folder_path)

        # split images into train 0.6 and remaining
        train_images, remaining_images = train_test_split(images, test_size=0.4, random_state=42)

        # split remaining images into validation 0.25 and test 0.15
        validation_images, test_images = train_test_split(remaining_images, test_size=0.375, random_state=42)

        # copy TRAIN images to the TRAIN directory
        for image in train_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(train_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)

        # copy VALIDATION images to the VALIDATION directory
        for image in validation_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(validation_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)

        # copy TEST images to the TEST directory
        for image in test_images:
            src = os.path.join(folder_path, image)
            dst = os.path.join(test_dir, class_name, image)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy2(src, dst)

# %% [markdown]
# ## Augmentation

# %%
# !pip install tensorflow==2.16.1

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img_width, img_height = 224, 224 # Image size to be used

# %%
train_datagen = ImageDataGenerator(
    rescale = 1/255.0,
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    fill_mode = 'nearest',
    brightness_range = [0.8, 1.2]
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (img_width, img_height),
    batch_size = 32,
    class_mode ='categorical'
)
# Out:
# Found 144 images belonging to 4 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 60 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 40 images belonging to 4 classes.

# %% [markdown]
# # Feature Extraction

# %%
import cv2
import random
import numpy as np

from collections import Counter
from sklearn.cluster import KMeans
from sklearn.feature_extraction import image

# %matplotlib inline

# %% [markdown]
# ## RGB Extraction

# %%
# convert the hex values
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
# accept both file paths and numpy array
def get_image(image):
    if isinstance(image, str):  # when image is a file path
        image = cv2.imread(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
def get_colors(image, number_of_colors):

    modified_image = cv2.resize(image, (img_width, img_height), interpolation=cv2.INTER_AREA)
    modified_image = modified_image.reshape(modified_image.shape[0] * modified_image.shape[1], 3)

    # warning: default value for n_init will change from 10 to 'auto' in scikit-learn version 1.4
    clf = KMeans(n_clusters=number_of_colors, n_init=10)
    labels = clf.fit_predict(modified_image)

    counts = Counter(labels)
    center_colors = clf.cluster_centers_

    # ordered colors by iterating through the keys
    ordered_colors = [center_colors[i] / 255 for i in counts.keys()]
    rgb_colors = [ordered_colors[i] * 255 for i in counts.keys()]

    return rgb_colors # a list of features

# %%
# check the RGB arrays returns
for i in range(3):
    # select a random folder from TRAIN dataset
    folder = random.choice(os.listdir(train_dir))
    folder_path = os.path.join(train_dir, folder)
    image_files = os.listdir(folder_path)

     # select a random image from the folder
    image_file = random.choice(image_files)
    image_path = os.path.join(folder_path, image_file)

    # return the RGB arrays
    print(image_path)
    print(get_colors(get_image(image_path), 3))
# Out:
# /content/drive/MyDrive/bangkit/dataset_iqbal/train/FN/FN (18).png
# [array([159.81267016, 198.63329843,  97.88      ]), array([ 86.73201175, 125.68526676,  28.28279491]), array([252.50104764, 253.39474333, 251.13625439])]
# /content/drive/MyDrive/bangkit/dataset_iqbal/train/-N/-N (37).png
# [array([152.7936986 , 143.48384107, 100.35283216]), array([190.63221358, 191.75401651, 194.84715193]), array([118.03767972, 152.83853908,  12.46289869])]
# /content/drive/MyDrive/bangkit/dataset_iqbal/train/FN/FN (34).png
# [array([168.0374271 , 196.10523109,  81.4593089 ]), array([40.54694249, 86.33363643,  5.43267409]), array([108.73797568, 158.55033346,  13.43264025])]

# %% [markdown]
# ## Extract from Directories

# %%
# lists and array to store the features and labels
train_features = []
train_labels = np.empty((0,), dtype=str)

validation_features = []
validation_labels = np.empty((0,), dtype=str)

test_features = []
test_labels = np.empty((0,), dtype=str)

# %%
# iterate over the TRAIN directory
for folder_name in os.listdir(train_dir):
    folder_path = os.path.join(train_dir, folder_name)

    # extract if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)

            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = train_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the train_features list
                train_features.append(features)
                train_labels = np.concatenate((train_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
train_features = np.array(train_features)

# %%
# print the shape of the TRAIN arrays
print("Train Features Shape:", train_features.shape)
print("Train Labels Shape:", train_labels.shape)
# Out:
# Train Features Shape: (144, 3, 3)
# Train Labels Shape: (144,)

# %%
# iterate over the VALIDATION directory
for folder_name in os.listdir(validation_dir):
    folder_path = os.path.join(validation_dir, folder_name)

    # check if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)

            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = validation_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the validation_features list
                validation_features.append(features)
                validation_labels = np.concatenate((validation_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
validation_features = np.array(validation_features)

# %%
# print the shape of the VALIDATION arrays
print("Validation Features Shape:", validation_features.shape)
print("Validation Labels Shape:", validation_labels.shape)
# Out:
# Validation Features Shape: (60, 3, 3)
# Validation Labels Shape: (60,)

# %%
# iterate over the TEST directory
for folder_name in os.listdir(test_dir):
    folder_path = os.path.join(test_dir, folder_name)

    # check if the item is a directory
    if os.path.isdir(folder_path):
        # iterate over the files in the current dir
        for file_name in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file_name)

            # check if the item is a file
            if os.path.isfile(file_path):
                # extract features from the image
                image = get_image(file_path)
                preprocessed_image = test_datagen.random_transform(image)
                features = get_colors(preprocessed_image, 3)

                # append the features to the test_features list
                test_features.append(features)
                test_labels = np.concatenate((test_labels, np.array([folder_name])), axis=0)

# %%
# convert to a numpy array
test_features = np.array(test_features)

# %%
# print the shape of the TEST arrays
print("Test Features Shape:", test_features.shape)
print("Test Labels Shape:", test_labels.shape)
# Out:
# Test Features Shape: (40, 3, 3)
# Test Labels Shape: (40,)

# %% [markdown]
# # Model

# %% [markdown]
# ## RGB Model

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
model = tf.keras.Sequential([
    layers.Conv1D(32, 1, activation='relu', input_shape=(3, 3)),
    layers.Conv1D(64, 1, activation='relu'),
    layers.Conv1D(128, 1, activation='relu'),

    layers.LSTM(32, return_sequences=True),
    layers.LSTM(64),

    layers.Flatten(),

    layers.Dense(64, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(128, activation='relu'),

    layers.Dropout(0.5),

    layers.Dense(4, activation='softmax')
])

# %%
optimizer = tf.keras.optimizers.RMSprop()
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 3, 32)             128
#
#  conv1d_1 (Conv1D)           (None, 3, 64)             2112
#
#  conv1d_2 (Conv1D)           (None, 3, 128)            8320
#
#  lstm (LSTM)                 (None, 3, 32)             20608
#
#  lstm_1 (LSTM)               (None, 64)                24832
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 73156 (285.77 KB)
# Trainable params: 73156 (285.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Model Training

# %%
import numpy as np
import tensorflow as tf

from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping

# %%
label_mapping = {"FN": 0, "-N": 1, "-P": 2, "-K": 3}

# %%
# map string labels to integer values
train_labels_mapped = np.array([label_mapping[label] for label in train_labels])
validation_labels_mapped = np.array([label_mapping[label] for label in validation_labels])
test_labels_mapped = np.array([label_mapping[label] for label in test_labels])

# one-hot encode the mapped labels
train_labels_one_hot = to_categorical(train_labels_mapped)
validation_labels_one_hot = to_categorical(validation_labels_mapped)
test_labels_one_hot = to_categorical(test_labels_mapped)

# %%
# define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit(
    train_features,
    train_labels_one_hot,
    epochs=400,
    batch_size=64,
    validation_data=(validation_features, validation_labels_one_hot)
)
# Out:
# Epoch 1/400
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9800 - val_accuracy: 0.8333
# Epoch 2/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9965 - val_accuracy: 0.8333
# Epoch 3/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0340 - val_accuracy: 0.8167
# Epoch 4/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0243 - val_accuracy: 0.8333
# Epoch 5/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1871 - val_accuracy: 0.7667
# Epoch 6/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7477 - accuracy: 0.8611 - val_loss: 1.2534 - val_accuracy: 0.7333
# Epoch 7/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4791 - accuracy: 0.9167 - val_loss: 0.7103 - val_accuracy: 0.8333
# Epoch 8/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0256 - accuracy: 0.9931 - val_loss: 0.7427 - val_accuracy: 0.8500
# Epoch 9/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.7762 - val_accuracy: 0.8500
# Epoch 10/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.7896 - val_accuracy: 0.8500
# Epoch 11/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.8500
# Epoch 12/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.8325 - val_accuracy: 0.8333
# Epoch 13/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8482 - val_accuracy: 0.8333
# Epoch 14/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0179 - accuracy: 0.9931 - val_loss: 1.0691 - val_accuracy: 0.8167
# Epoch 15/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0103 - accuracy: 0.9931 - val_loss: 0.9223 - val_accuracy: 0.8500
# Epoch 16/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0161 - accuracy: 0.9931 - val_loss: 0.8558 - val_accuracy: 0.8333
# Epoch 17/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0605 - accuracy: 0.9861 - val_loss: 1.0490 - val_accuracy: 0.8167
# Epoch 18/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0678 - accuracy: 0.9722 - val_loss: 2.0657 - val_accuracy: 0.6833
# Epoch 19/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7302 - accuracy: 0.8403 - val_loss: 0.8447 - val_accuracy: 0.8000
# Epoch 20/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1282 - accuracy: 0.9514 - val_loss: 0.9639 - val_accuracy: 0.8500
# Epoch 21/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 0.8873 - val_accuracy: 0.8667
# Epoch 22/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0163 - accuracy: 0.9931 - val_loss: 1.0325 - val_accuracy: 0.8333
# Epoch 23/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.0008 - val_accuracy: 0.8500
# Epoch 24/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0057 - val_accuracy: 0.8500
# Epoch 25/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.9992 - val_accuracy: 0.8500
# Epoch 26/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.0160 - val_accuracy: 0.8500
# Epoch 27/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0354 - val_accuracy: 0.8500
# Epoch 28/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0647 - val_accuracy: 0.8500
# Epoch 29/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0858 - val_accuracy: 0.8333
# Epoch 30/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0846 - val_accuracy: 0.8500
# Epoch 31/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1193 - val_accuracy: 0.8333
# Epoch 32/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1195 - val_accuracy: 0.8333
# Epoch 33/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1424 - val_accuracy: 0.8333
# Epoch 34/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2997 - val_accuracy: 0.8167
# Epoch 35/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2365 - accuracy: 0.9167 - val_loss: 1.3325 - val_accuracy: 0.7167
# Epoch 36/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6395 - accuracy: 0.8264 - val_loss: 1.0601 - val_accuracy: 0.8000
# Epoch 37/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1142 - accuracy: 0.9653 - val_loss: 0.9633 - val_accuracy: 0.8167
# Epoch 38/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1560 - accuracy: 0.9375 - val_loss: 0.9043 - val_accuracy: 0.8333
# Epoch 39/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.8468 - val_accuracy: 0.8333
# Epoch 40/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.8489 - val_accuracy: 0.8167
# Epoch 41/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8064 - val_accuracy: 0.8333
# Epoch 42/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8032 - val_accuracy: 0.8333
# Epoch 43/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.8461 - val_accuracy: 0.8500
# Epoch 44/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.8657 - val_accuracy: 0.8333
# Epoch 45/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8309 - val_accuracy: 0.8333
# Epoch 46/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.8254 - val_accuracy: 0.8500
# Epoch 47/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.8425 - val_accuracy: 0.8333
# Epoch 48/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.8474 - val_accuracy: 0.8500
# Epoch 49/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8347 - val_accuracy: 0.8333
# Epoch 50/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9959 - val_accuracy: 0.8333
# Epoch 51/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.9668 - val_accuracy: 0.8333
# Epoch 52/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9436 - val_accuracy: 0.8333
# Epoch 53/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.9420 - val_accuracy: 0.8333
# Epoch 54/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9860 - val_accuracy: 0.8500
# Epoch 55/400
# 3/3 [==============================] - 0s 18ms/step - loss: 8.7713e-04 - accuracy: 1.0000 - val_loss: 1.0115 - val_accuracy: 0.8167
# Epoch 56/400
# 3/3 [==============================] - 0s 18ms/step - loss: 8.7323e-04 - accuracy: 1.0000 - val_loss: 1.0102 - val_accuracy: 0.8333
# Epoch 57/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.8500
# Epoch 58/400
# 3/3 [==============================] - 0s 19ms/step - loss: 8.7040e-04 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.8500
# Epoch 59/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0725 - val_accuracy: 0.8500
# Epoch 60/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1725 - val_accuracy: 0.8167
# Epoch 61/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1577 - accuracy: 0.9514 - val_loss: 2.8682 - val_accuracy: 0.6000
# Epoch 62/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5501 - accuracy: 0.8819 - val_loss: 0.8112 - val_accuracy: 0.8333
# Epoch 63/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0990 - accuracy: 0.9722 - val_loss: 0.8235 - val_accuracy: 0.8500
# Epoch 64/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0295 - accuracy: 0.9931 - val_loss: 0.8864 - val_accuracy: 0.8333
# Epoch 65/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.8526 - val_accuracy: 0.9000
# Epoch 66/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.8707 - val_accuracy: 0.8833
# Epoch 67/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.9090 - val_accuracy: 0.8833
# Epoch 68/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9088 - val_accuracy: 0.8833
# Epoch 69/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9070 - val_accuracy: 0.8833
# Epoch 70/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.9489 - val_accuracy: 0.8667
# Epoch 71/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9495 - val_accuracy: 0.8833
# Epoch 72/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.9882 - val_accuracy: 0.8833
# Epoch 73/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.8982 - val_accuracy: 0.9167
# Epoch 74/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9229 - val_accuracy: 0.9000
# Epoch 75/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9463 - val_accuracy: 0.9000
# Epoch 76/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.1751 - val_accuracy: 0.8500
# Epoch 77/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0106 - val_accuracy: 0.8500
# Epoch 78/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.8333
# Epoch 79/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6151 - accuracy: 0.9236 - val_loss: 1.9339 - val_accuracy: 0.7167
# Epoch 80/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4704 - accuracy: 0.8681 - val_loss: 0.5694 - val_accuracy: 0.8667
# Epoch 81/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0578 - accuracy: 0.9792 - val_loss: 0.7538 - val_accuracy: 0.8333
# Epoch 82/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0253 - accuracy: 0.9861 - val_loss: 0.8312 - val_accuracy: 0.8000
# Epoch 83/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.7916 - val_accuracy: 0.7833
# Epoch 84/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0086 - accuracy: 0.9931 - val_loss: 0.9572 - val_accuracy: 0.7667
# Epoch 85/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.9453 - val_accuracy: 0.7500
# Epoch 86/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9892 - val_accuracy: 0.7500
# Epoch 87/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.9710 - val_accuracy: 0.7833
# Epoch 88/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.0115 - val_accuracy: 0.7500
# Epoch 89/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.3316 - val_accuracy: 0.7667
# Epoch 90/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2047 - accuracy: 0.9514 - val_loss: 1.2392 - val_accuracy: 0.7667
# Epoch 91/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2385 - accuracy: 0.9306 - val_loss: 0.9647 - val_accuracy: 0.7833
# Epoch 92/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2460 - accuracy: 0.9306 - val_loss: 1.6083 - val_accuracy: 0.7667
# Epoch 93/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1653 - accuracy: 0.9583 - val_loss: 0.6831 - val_accuracy: 0.8500
# Epoch 94/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0198 - accuracy: 0.9861 - val_loss: 0.7541 - val_accuracy: 0.8167
# Epoch 95/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7807 - val_accuracy: 0.8167
# Epoch 96/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.7826 - val_accuracy: 0.8333
# Epoch 97/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.7827 - val_accuracy: 0.8500
# Epoch 98/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8213 - val_accuracy: 0.8333
# Epoch 99/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8470 - val_accuracy: 0.8333
# Epoch 100/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.7967 - val_accuracy: 0.8500
# Epoch 101/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8160 - val_accuracy: 0.8667
# Epoch 102/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8397 - val_accuracy: 0.8667
# Epoch 103/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8286 - val_accuracy: 0.8500
# Epoch 104/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8715 - val_accuracy: 0.8500
# Epoch 105/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8587 - val_accuracy: 0.8500
# Epoch 106/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8554 - val_accuracy: 0.8500
# Epoch 107/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9296 - val_accuracy: 0.8500
# Epoch 108/400
# 3/3 [==============================] - 0s 18ms/step - loss: 7.8167e-04 - accuracy: 1.0000 - val_loss: 0.9438 - val_accuracy: 0.8500
# Epoch 109/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.0710 - val_accuracy: 0.8167
# Epoch 110/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1750 - accuracy: 0.9653 - val_loss: 3.5420 - val_accuracy: 0.6833
# Epoch 111/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8777 - accuracy: 0.8333 - val_loss: 1.3802 - val_accuracy: 0.8333
# Epoch 112/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0567 - accuracy: 0.9861 - val_loss: 1.5655 - val_accuracy: 0.8000
# Epoch 113/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0911 - accuracy: 0.9792 - val_loss: 1.2663 - val_accuracy: 0.8167
# Epoch 114/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.8167
# Epoch 115/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.8167
# Epoch 116/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.2466 - val_accuracy: 0.8167
# Epoch 117/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.2418 - val_accuracy: 0.8167
# Epoch 118/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0127 - accuracy: 0.9931 - val_loss: 1.1756 - val_accuracy: 0.8500
# Epoch 119/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.1620 - val_accuracy: 0.8333
# Epoch 120/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1607 - val_accuracy: 0.8500
# Epoch 121/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.1650 - val_accuracy: 0.8500
# Epoch 122/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.1921 - val_accuracy: 0.8500
# Epoch 123/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.1884 - val_accuracy: 0.8500
# Epoch 124/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1911 - val_accuracy: 0.8500
# Epoch 125/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.1944 - val_accuracy: 0.8500
# Epoch 126/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.1827 - val_accuracy: 0.8500
# Epoch 127/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1881 - val_accuracy: 0.8500
# Epoch 128/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2167 - val_accuracy: 0.8333
# Epoch 129/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2484 - val_accuracy: 0.8333
# Epoch 130/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2688 - val_accuracy: 0.8333
# Epoch 131/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.3515 - val_accuracy: 0.8333
# Epoch 132/400
# 3/3 [==============================] - 0s 18ms/step - loss: 5.4605e-04 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.8333
# Epoch 133/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1462 - val_accuracy: 0.8500
# Epoch 134/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.3095 - val_accuracy: 0.8500
# Epoch 135/400
# 3/3 [==============================] - 0s 18ms/step - loss: 8.4813e-04 - accuracy: 1.0000 - val_loss: 1.4018 - val_accuracy: 0.8500
# Epoch 136/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1774 - accuracy: 0.9722 - val_loss: 4.3650 - val_accuracy: 0.6167
# Epoch 137/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8304 - accuracy: 0.8611 - val_loss: 1.0038 - val_accuracy: 0.8333
# Epoch 138/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0290 - accuracy: 0.9931 - val_loss: 1.0816 - val_accuracy: 0.8500
# Epoch 139/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.0750 - val_accuracy: 0.8500
# Epoch 140/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0838 - val_accuracy: 0.8500
# Epoch 141/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0817 - val_accuracy: 0.8500
# Epoch 142/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0754 - val_accuracy: 0.8500
# Epoch 143/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0802 - val_accuracy: 0.8500
# Epoch 144/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.0676 - val_accuracy: 0.8500
# Epoch 145/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0759 - val_accuracy: 0.8500
# Epoch 146/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0814 - val_accuracy: 0.8500
# Epoch 147/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0233 - val_accuracy: 0.8333
# Epoch 148/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0594 - val_accuracy: 0.8500
# Epoch 149/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0950 - val_accuracy: 0.8667
# Epoch 150/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1187 - val_accuracy: 0.8500
# Epoch 151/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1571 - val_accuracy: 0.8500
# Epoch 152/400
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1649 - val_accuracy: 0.8500
# Epoch 153/400
# 3/3 [==============================] - 0s 17ms/step - loss: 9.1661e-04 - accuracy: 1.0000 - val_loss: 1.2051 - val_accuracy: 0.8500
# Epoch 154/400
# 3/3 [==============================] - 0s 18ms/step - loss: 7.2737e-04 - accuracy: 1.0000 - val_loss: 1.2079 - val_accuracy: 0.8667
# Epoch 155/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1802 - accuracy: 0.9583 - val_loss: 1.1269 - val_accuracy: 0.8000
# Epoch 156/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1464 - accuracy: 0.9722 - val_loss: 1.6506 - val_accuracy: 0.7833
# Epoch 157/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1203 - accuracy: 0.9722 - val_loss: 1.1927 - val_accuracy: 0.8000
# Epoch 158/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0791 - accuracy: 0.9792 - val_loss: 1.0363 - val_accuracy: 0.8500
# Epoch 159/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1201 - accuracy: 0.9861 - val_loss: 1.3923 - val_accuracy: 0.7833
# Epoch 160/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.
400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0376 - accuracy: 0.9931 - val_loss: 1.3544 - val_accuracy: 0.7667
# Epoch 189/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0439 - accuracy: 0.9792 - val_loss: 1.1771 - val_accuracy: 0.7833
# Epoch 190/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.0811 - val_accuracy: 0.8000
# Epoch 191/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0485 - val_accuracy: 0.8000
# Epoch 192/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0241 - val_accuracy: 0.8000
# Epoch 193/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.8000
# Epoch 194/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0183 - val_accuracy: 0.8000
# Epoch 195/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0262 - val_accuracy: 0.8000
# Epoch 196/400
# 3/3 [==============================] - 0s 18ms/step - loss: 9.7223e-04 - accuracy: 1.0000 - val_loss: 1.0121 - val_accuracy: 0.8000
# Epoch 197/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.0094 - val_accuracy: 0.8167
# Epoch 198/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.0404 - val_accuracy: 0.8000
# Epoch 199/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.9704 - val_accuracy: 0.8333
# Epoch 200/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.1101 - val_accuracy: 0.7833
# Epoch 201/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0947 - val_accuracy: 0.7833
# Epoch 202/400
# 3/3 [==============================] - 0s 19ms/step - loss: 9.3228e-04 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.7833
# Epoch 203/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1026 - val_accuracy: 0.7667
# Epoch 204/400
# 3/3 [==============================] - 0s 18ms/step - loss: 8.5772e-04 - accuracy: 1.0000 - val_loss: 1.0472 - val_accuracy: 0.7833
# Epoch 205/400
# 3/3 [==============================] - 0s 18ms/step - loss: 6.0375e-04 - accuracy: 1.0000 - val_loss: 1.1767 - val_accuracy: 0.7833
# Epoch 206/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1047 - val_accuracy: 0.8167
# Epoch 207/400
# 3/3 [==============================] - 0s 20ms/step - loss: 7.4319e-04 - accuracy: 1.0000 - val_loss: 1.1031 - val_accuracy: 0.8000
# Epoch 208/400
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0773 - accuracy: 0.9792 - val_loss: 3.6445 - val_accuracy: 0.6000
# Epoch 209/400
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9708 - accuracy: 0.8403 - val_loss: 1.3118 - val_accuracy: 0.8000
# Epoch 210/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3056 - accuracy: 0.9375 - val_loss: 0.8867 - val_accuracy: 0.8667
# Epoch 211/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0896 - accuracy: 0.9861 - val_loss: 0.8947 - val_accuracy: 0.8500
# Epoch 212/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9480 - val_accuracy: 0.8333
# Epoch 213/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9691 - val_accuracy: 0.8333
# Epoch 214/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.8167
# Epoch 215/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.9727 - val_accuracy: 0.8500
# Epoch 216/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9787 - val_accuracy: 0.8500
# Epoch 217/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0177 - val_accuracy: 0.8500
# Epoch 218/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0190 - val_accuracy: 0.8500
# Epoch 219/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.0567 - val_accuracy: 0.8500
# Epoch 220/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1704 - accuracy: 0.9583 - val_loss: 1.4758 - val_accuracy: 0.7167
# Epoch 221/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1846 - accuracy: 0.9236 - val_loss: 1.2690 - val_accuracy: 0.7833
# Epoch 222/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.1177 - val_accuracy: 0.8000
# Epoch 223/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0318 - val_accuracy: 0.8333
# Epoch 224/400
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0692 - val_accuracy: 0.8167
# Epoch 225/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss:
400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0497 - accuracy: 0.9722 - val_loss: 1.2538 - val_accuracy: 0.8167
# Epoch 348/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.2355 - val_accuracy: 0.8000
# Epoch 349/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2360 - val_accuracy: 0.8000
# Epoch 350/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.2166 - val_accuracy: 0.8000
# Epoch 351/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2194 - val_accuracy: 0.8000
# Epoch 352/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2682 - val_accuracy: 0.8000
# Epoch 353/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8000
# Epoch 354/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.8000
# Epoch 355/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2432 - val_accuracy: 0.8000
# Epoch 356/400
# 3/3 [==============================] - 0s 19ms/step - loss: 7.9279e-04 - accuracy: 1.0000 - val_loss: 1.2244 - val_accuracy: 0.8167
# Epoch 357/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2363 - val_accuracy: 0.8167
# Epoch 358/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3416 - val_accuracy: 0.8000
# Epoch 359/400
# 3/3 [==============================] - 0s 19ms/step - loss: 8.8130e-04 - accuracy: 1.0000 - val_loss: 1.3028 - val_accuracy: 0.8167
# Epoch 360/400
# 3/3 [==============================] - 0s 19ms/step - loss: 5.9751e-04 - accuracy: 1.0000 - val_loss: 1.2935 - val_accuracy: 0.8167
# Epoch 361/400
# 3/3 [==============================] - 0s 18ms/step - loss: 4.5193e-04 - accuracy: 1.0000 - val_loss: 1.2877 - val_accuracy: 0.8167
# Epoch 362/400
# 3/3 [==============================] - 0s 18ms/step - loss: 7.4727e-04 - accuracy: 1.0000 - val_loss: 1.2630 - val_accuracy: 0.8167
# Epoch 363/400
# 3/3 [==============================] - 0s 19ms/step - loss: 5.2405e-04 - accuracy: 1.0000 - val_loss: 1.2836 - val_accuracy: 0.8167
# Epoch 364/400
# 3/3 [==============================] - 0s 19ms/step - loss: 9.3380e-04 - accuracy: 1.0000 - val_loss: 1.2638 - val_accuracy: 0.8167
# Epoch 365/400
# 3/3 [==============================] - 0s 19ms/step - loss: 7.3914e-04 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.8333
# Epoch 366/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1923 - val_accuracy: 0.8333
# Epoch 367/400
# 3/3 [==============================] - 0s 18ms/step - loss: 2.9425e-04 - accuracy: 1.0000 - val_loss: 1.1936 - val_accuracy: 0.8333
# Epoch 368/400
# 3/3 [==============================] - 0s 19ms/step - loss: 7.5790e-04 - accuracy: 1.0000 - val_loss: 1.2666 - val_accuracy: 0.8500
# Epoch 369/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0178 - accuracy: 0.9931 - val_loss: 2.0259 - val_accuracy: 0.7000
# Epoch 370/400
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6281 - accuracy: 0.7847 - val_loss: 1.4286 - val_accuracy: 0.7167
# Epoch 371/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2384 - accuracy: 0.9583 - val_loss: 1.3937 - val_accuracy: 0.7667
# Epoch 372/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.3363 - val_accuracy: 0.7667
# Epoch 373/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0142 - accuracy: 0.9931 - val_loss: 1.2999 - val_accuracy: 0.7500
# Epoch 374/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2812 - val_accuracy: 0.7500
# Epoch 375/400
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2704 - val_accuracy: 0.7667
# Epoch 376/400
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2500 - val_accuracy: 0.7667
# Epoch 377/400
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1
# 3/3 [==============================] - 0s 18ms/step - loss: 2.2398e-04 - accuracy: 1.0000 - val_loss: 1.1907 - val_accuracy: 0.8167
# Epoch 399/400
# 3/3 [==============================] - 0s 19ms/step - loss: 2.5361e-04 - accuracy: 1.0000 - val_loss: 1.2098 - val_accuracy: 0.8167
# Epoch 400/400
# 3/3 [==============================] - 0s 19ms/step - loss: 1.4161e-04 - accuracy: 1.0000 - val_loss: 1.1836 - val_accuracy: 0.8000

# %%
loss, accuracy = model.evaluate(test_features, test_labels_one_hot)
print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 2.4460 - accuracy: 0.7250
# Loss: 2.4459757804870605
# Accuracy: 0.7250000238418579

# %% [markdown]
# ## Evaluation

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report

# %%
# convert predicted probabilities to labels
y_pred_probs = model.predict(test_features)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
# convert test_labels to numeric labels
numeric_labels = np.array([label_mapping[label] for label in test_labels])

# %%
# calculate confusion matrix
confusion = confusion_matrix(numeric_labels, y_pred_labels)

# %%
# visualize the confusion matrix
plt.figure(figsize=(8, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', cbar=False)

plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# generate classification report
report = classification_report(numeric_labels, y_pred_labels)
print(report)

# %%
def plot_training_history(history):
    # get the training and validation metrics
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(accuracy, 'g', label='Training Accuracy')
    plt.plot(val_accuracy, 'b', label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.show()

    # plot loss
    plt.figure(figsize=(6, 4))
    plt.plot(loss, 'g', label='Training Loss')
    plt.plot(val_loss, 'b', label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.show()

# %%
plot_training_history(history)

# %% [markdown]
# # Predict and Recommendation

# %%
from PIL import Image

# %%
def get_input(image_path):
    image = get_image(image_path)
    image = get_colors(image, 3)
    image = np.expand_dims(image, axis=0)  # an extra dimension for batch size
    return image

# %%
# predict function for inference
def predict(model, img):
    predictions = model.predict(img)
    predicted_class = class_names[np.argmax(predictions[0])]

    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
def generate_custom_paragraph(predicted_label):

    default = '\nSaran lainnya: \n 1. Pertahankan pH larutan nutrisi hidroponik (antara 5.5 hingga 6.5). \n 2. Pastikan sistem hidroponik memiliki sirkulasi air yang baik \n 3. Gunakan sistem filtrasi air jika diperlukan.'
    # Define a mapping of labels to custom paragraphs
    mapping = { # tinggal revisi paragraf
        'FN': 'Selada yang  memiliki cukup nutrisi dapat mengalami pertumbuhan yang baik dan warna daun yang sehat. \n Dalam kondisi ini, tidak terdapat kekurangan nutrisi spesifik yang perlu diatasi. \n' + default,
        '-N': 'Selada yang kekurangan nitrogen dapat mengalami pertumbuhan terhambat, warna daun kekuningan, \n serta kualitas tanaman yang rendah. Untuk mengatasi masalah ini, disarankan untuk meningkatkan \n pemupukan nitrogen menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk ZA Petro \n 2. KNO3 Crystal \n 3. Mutiara Sprinter Pupuk NPK 20-10-10 \n' + default,
        '-P': 'Selada yang kekurangan fosfor dapat mengalami pertumbuhan terhambat, perkembangan akar yang terganggu, \n warna daun yang keunguan dan pucat, serta kualitas tanaman yang rendah. Untuk mengatasi masalah ini, \n disarankan untuk meningkatkan pemupukan fosfor menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk DAP ULTRADAP pak tani \n 2. Pupuk MAP MerokeMAP \n 3. Pupuk TSP MerokeTSP \n' + default,
        '-K': 'Selada yang kekurangan kalium dapat mengalami pertumbuhan terhambat, perkembangan akar yang terganggu, \n warna daun kecoklatan, serta resistensi terhadap penyakit yang rendah. Untuk mengatasi masalah ini, \n disarankan untuk meningkatkan pemupukan menggunakan pupuk yang kaya akan nutrisi tersebut. \n 1. Pupuk KNO3 Crystal \n 2. Pupuk KCL MerokeMOP \n 3. Pupuk ZK Cap Goldenmax \n' + default,
    }

    # Get the custom paragraph based on the predicted label
    custom_paragraph = mapping.get(predicted_label, 'Tidak ada rekomendasi untuk saat ini')

    return custom_paragraph

# %%
# get a sample image
image = get_image('/content/drive/MyDrive/bangkit/dataset_bilal/lettuce/-P/-P (38).png')

# predict the image
input_image = get_input(image)
predicted_class, confidence = predict(model, input_image)

# convert predicted class
label_mapping = {"FN": "Fully Nutritional", "-N": "Nitrogen Deficiency", "-P": "Phosporus Deficiency", "-K": "Kalium Deficiency"}
predicted_class_mapped = label_mapping[predicted_class]

plt.imshow(image)
plt.title(f"Diagnosis: {predicted_class_mapped}\n Confidence: {confidence}%\n\n Notes: {generate_custom_paragraph(predicted_class)}")
plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 176ms/step
# (-0.5, 1022.5, 1004.5, -0.5)

# %% [markdown]
# # Save Keras Model

# %%
import tensorflow as tf

# %%
# saved to .h5 format
model.save(base_dir + '/lettuce_model.h5')
model = tf.keras.models.load_model(base_dir + '/lettuce_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# saved to tensorflow
export_dir = base_dir + '/saved_model_capstone'
tf.saved_model.save(model, export_dir=export_dir)

# %%
mode = ""

if mode == 'Storage':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_SIZE
elif mode == 'Speed':
    optimization = tf.lite.Optimize.OPTIMIZE_FOR_LATENCY
else:
    optimization = tf.lite.Optimize.DEFAULT

# %%
# convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
converter.optimizations = [optimization]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]

# disable experimental lowering of tensor list ops
converter.experimental_lower_tensor_list_ops = False

tflite_model = converter.convert()

# %%
# save the TensorFlow Lite model
with open('lettuce_model.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
# !tensorflowjs_converter --input_format keras {saved_model_path} ./

# !zip submission.zip *.bin model.json
